# %% [markdown]
# # Data loading
#
# Testing data loading

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2

# %%
from src.datasources import seas5, era5, emdat

# %%
pcode = "SS"
issued_month = 6
valid_months = [7, 8, 9]

# %% [markdown]
# ## SEAS5

# %%
df_test = seas5.load_seas5(
    pcode=pcode, issued_month=issued_month, valid_months=valid_months
)

# %%
df_test
# Out:
#     iso3 pcode valid_date issued_date  ...        max  count         sum       std
# 0    SSD    SS 1991-07-01  1991-06-01  ...   9.161789  21029  126923.664  1.558541
# 1    SSD    SS 1991-08-01  1991-06-01  ...   9.267362  21029  138405.060  1.751883
# 2    SSD    SS 1991-09-01  1991-06-01  ...   8.105219  21029   93453.000  1.421659
# 3    SSD    SS 1992-07-01  1992-06-01  ...   9.199913  21029  122923.230  1.535856
# 4    SSD    SS 1992-08-01  1992-06-01  ...   9.518093  21029  140215.470  1.620025
# ..   ...   ...        ...         ...  ...        ...    ...         ...       ...
# 130  SSD    SS 2018-07-01  2018-06-01  ...  11.074794  21029  142861.170  1.841968
# 131  SSD    SS 1983-09-01  1983-06-01  ...   8.189995  21029  110351.914  1.244322
# 132  SSD    SS 2025-07-01  2025-06-01  ...  11.148646  21029  152306.140  1.774417
# 133  SSD    SS 2025-08-01  2025-06-01  ...  11.649343  21029  166936.620  1.734435
# 134  SSD    SS 2025-09-01  2025-06-01  ...  10.411767  21029  144690.720  1.445902
#
# [135 rows x 13 columns]

# %%
df_test_yearly = seas5.load_seas5_yearly(
    pcode=pcode, issued_month=issued_month, valid_months=valid_months
)

# %%
df_test_yearly.set_index("year").plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ## ERA5

# %%
df_test_era5 = era5.load_era5(pcode=pcode, valid_months=valid_months)

# %%
df_test_era5["valid_date"].max()
# Out:
# Timestamp('2024-09-01 00:00:00')

# %%
df_test_era5_yearly = era5.load_era5_yearly(
    pcode=pcode, valid_months=valid_months
)

# %%
df_test_era5_yearly.set_index("year").plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ## EM-DAT

# %%
df_test_emdat = emdat.load_emdat(iso3="ssd", disaster_type="Flood")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
df_test_emdat
# Out:
#            DisNo. Historic  ...  Entry Date Last Update
# 0   2008-0331-SSD       No  ...  2008-08-19  2023-09-25
# 1   2008-0520-SSD       No  ...  2008-11-18  2023-09-25
# 2   2008-0554-SSD       No  ...  2008-11-26  2023-09-25
# 3   2010-0579-SSD       No  ...  2016-05-10  2023-09-25
# 4   2010-0703-SSD       No  ...  2014-05-12  2023-09-25
# 5   2012-0473-SSD       No  ...  2012-11-21  2023-09-25
# 6   2012-0476-SSD       No  ...  2012-11-22  2023-09-25
# 7   2013-0425-SSD       No  ...  2013-10-30  2023-09-25
# 8   2013-0453-SSD       No  ...  2014-04-04  2023-09-25
# 9   2016-0327-SSD       No  ...  2016-09-15  2023-09-25
# 10  2019-0285-SSD       No  ...  2019-06-25  2023-09-25
# 11  2019-0486-SSD       No  ...  2019-10-22  2023-09-25
# 12  2020-0362-SSD       No  ...  2020-08-17  2023-09-25
# 13  2021-0481-SSD       No  ...  2021-08-11  2023-09-25
# 14  2022-0650-SSD       No  ...  2022-10-10  2023-09-26
# 15  2024-0673-SSD       No  ...  2024-09-24  2025-02-26
#
# [16 rows x 46 columns]
